# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "nba_hurt2.csv"
inj_df = pd.read_csv(file)

# %%
inj_uni_df = inj_df.groupby(["college"])
inj_uni_count = inj_uni_df["college"].count()
inj_uni = inj_uni_df["college"].unique()
inj_uni_dfa = pd.DataFrame({"Colleges":inj_uni,
                            "Count": inj_uni_count})
inj_uni_dfa.head()
inj_uni_dfb = inj_uni_dfa.sort_values(["Count"], ascending = False)
inj_uni_dfb
# Out:
#                                                                                              Colleges  \
# college
# University of California, Los Angeles                         [University of California, Los Angeles]
# University of Kentucky                                                       [University of Kentucky]
# Duke University                                                                     [Duke University]
# University of North Carolina                                           [University of North Carolina]
# University of Kansas                                                           [University of Kansas]
# University of Connecticut                                                 [University of Connecticut]
# University of Arizona                                                         [University of Arizona]
# University of Florida                                                         [University of Florida]
# University of Southern California                                 [University of Southern California]
# University of Texas at Austin                                         [University of Texas at Austin]
# Georgia Institute of Technology                                     [Georgia Institute of Technology]
# University of Washington                                                   [University of Washington]
# Syracuse University                                                             [Syracuse University]
# University of Memphis                                                         [University of Memphis]
# Wake Forest University                                                       [Wake Forest University]
# Indiana University                                                               [Indiana University]
# Louisiana State University                                               [Louisiana State University]
# Marquette University                                                           [Marquette University]
# Michigan State University                                                 [Michigan State University]
# Oklahoma State University                                                 [Oklahoma State University]
# University of Maryland                                                       [University of Maryland]
# Saint Joseph's University                                                 [Saint Joseph's University]
# Colorado State University                                                 [Colorado State University]
# University of Arkansas                                                       [University of Arkansas]
# University of Illinois at Urbana-Champaign               [University of Illinois at Urbana-Champaign]
# University of Alabama                                                         [University of Alabama]
# Ohio State University                                                         [Ohio State University]
# University of Missouri                                                       [University of Missouri]
# Stanford University                                                             [Stanford University]
# University of Louisville                                                   [University of Louisville]
# ...                                                                                               ...
# Norfolk State University                                                   [Norfolk State University]
# University of Louisiana at Lafayette                           [University of Louisiana at Lafayette]
# University of Houston                                                         [University of Houston]
# Southern Methodist University                                         [Southern Methodist University]
# Weber State University                                                       [Weber State University]
# Mississippi State University                                           [Mississippi State University]
# Alabama A&M University                                                       [Alabama A&M University]
# University of California, Santa Barbara                     [University of California, Santa Barbara]
# Rider University                                                                   [Rider University]
# Oregon State University                                                     [Oregon State University]
# Pennsylvania State University                                         [Pennsylvania State University]
# Ohio University                                                                     [Ohio University]
# West Virginia University                                                   [West Virginia University]
# St. Bonaventure University                                               [St. Bonaventure University]
# Texas Tech University                                                         [Texas Tech University]
# University of Rhode Island                                               [University of Rhode Island]
# Georgia State University                                                   [Georgia State University]
# Oakland University                                                               [Oakland University]
# University of Nebraska                                                       [University of Nebraska]
# Boston University                                                                 [Boston University]
# George Washington University                                           [George Washington University]
# California Polytechnic State University, San Lu...  [California Polytechnic State University, San ...
# Virginia Union University                                                 [Virginia Union University]
# University of Hawaii                                                           [University of Hawaii]
# Southeast Missouri State University                             [Southeast Missouri State University]
# University of Tulsa                                                             [University of Tulsa]
# Belmont University                                                               [Belmont University]
# Western Michigan University                                             [Western Michigan University]
# University of Arkansas at Little Rock                         [University of Arkansas at Little Rock]
# College of Charleston                                                         [College of Charleston]
#
#                                                     Count
# college
# University of California, Los Angeles                 888
# University of Kentucky                                600
# Duke University                                       592
# University of North Carolina                          548
# University of Kansas                                  542
# University of Connecticut                             430
# University of Arizona                                 358
# University of Florida                                 358
# University of Southern California                     302
# University of Texas at Austin                         290
# Georgia Institute of Technology                       270
# University of Washington                              266
# Syracuse University                                   248
# University of Memphis                                 230
# Wake Forest University                                222
# Indiana University                                    200
# Louisiana State University                            190
# Marquette University                                  174
# Michigan State University                             160
# Oklahoma State University                             148
# University of Maryland                                146
# Saint Joseph's University                             140
# Colorado State University                             136
# University of Arkansas                                128
# University of Illinois at Urbana-Champaign            124
# University of Alabama                                 122
# Ohio State University                                 112
# University of Missouri                                112
# Stanford University                                   112
# University of Louisville                              112
# ...                                                   ...
# Norfolk State University                                8
# University of Louisiana at Lafayette                    8
# University of Houston                                   8
# Southern Methodist University                           8
# Weber State University                                  6
# Mississippi State University                            6
# Alabama A&M University                                  6
# University of California, Santa Barbara                 6
# Rider University                                        6
# Oregon State University                                 6
# Pennsylvania State University                           4
# Ohio University                                         4
# West Virginia University                                4
# St. Bonaventure University                              4
# Texas Tech University                                   4
# University of Rhode Island                              4
# Georgia State University                                4
# Oakland University                                      2
# University of Nebraska                                  2
# Boston University                                       2
# George Washington University                            2
# California Polytechnic State University, San Lu...      2
# Virginia Union University                               2
# University of Hawaii                                    2
# Southeast Missouri State University                     2
# University of Tulsa                                     2
# Belmont University                                      2
# Western Michigan University                             2
# University of Arkansas at Little Rock                   2
# College of Charleston                                   2
#
# [146 rows x 2 columns]

# %%
inj_uni_dfb.describe()
# Out:
#             Count
# count  146.000000
# mean    85.136986
# std    131.780781
# min      2.000000
# 25%     12.000000
# 50%     46.000000
# 75%     87.500000
# max    888.000000

# %%
# %matplotlib notebook
x_axis = np.arange(len(inj_uni))
plt.bar(x_axis, inj_uni_count, label = "Colleges")
plt.xlabel("Colleges")
plt.ylabel("Injuries")
# Out:
# <img src="data:image/png;base64,..." width="998.4000761718807">
# Text(0, 0.5, 'Injuries')

# %%
# Out:
# <img src="data:image/png;base64,..." width="639.9999564034628">
# <BarContainer object of 146 artists>

# %%
plt.savefig("Injury_Colleges.png")
plt.show()
