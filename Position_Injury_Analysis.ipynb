# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
inj_file = "nba_hurt.csv"
inj_df = pd.read_csv(inj_file)

# %%
inj_df.head()
# Out:
#          Date     Team              name  \
# 0  2010-10-03    Bulls     Carlos Boozer
# 1  2010-10-08  Blazers        Jeff Ayres
# 2  2010-10-08     Nets       Troy Murphy
# 3  2010-10-12    Bucks  Darington Hobson
# 4  2010-10-12    Kings  Samuel Dalembert
#
#                                                Notes  year_start  year_end  \
# 0  fractured bone in right pinky finger (out inde...      2003.0    2015.0
# 1          torn ACL in right knee (out indefinitely)      2010.0    2016.0
# 2             strained lower back (out indefinitely)      2002.0    2013.0
# 3               surgery on left hip (out for season)      2012.0    2012.0
# 4             strained left groin (out indefinitely)      2002.0    2015.0
#
#   position height  weight          birth_date                   college
# 0      F-C    6-9   258.0   November 20, 1981           Duke University
# 1        F    6-9   240.0      April 29, 1987  Arizona State University
# ...

# %%
inj_pos_df = inj_df.groupby(["position"])
inj_pos_count = inj_pos_df["position"].count()
inj_pos = inj_pos_df["position"].unique()
inj_pos_dfa = pd.DataFrame({"Position":inj_pos, 
                            "Count": inj_pos_count})
inj_pos_dfa.head
# Out:
# <bound method NDFrame.head of          Position  Count
# position
# C             [C]    407
# C-F         [C-F]    345
# F             [F]   1688
# F-C         [F-C]    534
# F-G         [F-G]    237
# G             [G]   2522
# G-F         [G-F]    482>

# %%
inj_pos
inj_pos_count
# Out:
# position
# C       407
# C-F     345
# F      1688
# F-C     534
# F-G     237
# G      2522
# G-F     482
# Name: position, dtype: int64

# %%
# %matplotlib notebook

# %%
plt.bar(inj_pos_dfa["Position"], inj_pos_dfa["Count"], label = "Positions")
# Out:
# <img src="data:image/png;base64,..." width="639.9999564034628">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-cd894bc33bd3> in <module>
# ----> 1 plt.bar(inj_pos_dfa["Position"], inj_pos_dfa["Count"], label = "Positions")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...
